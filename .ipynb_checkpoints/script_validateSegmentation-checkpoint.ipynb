# %%
import SimpleITK as sitk
import numpy as np
import scipy
import os, sys, time, datetime
import pathlib
import matplotlib.pyplot as plt
import re
import Metrics
import ImageProcessing

# %%
savefig_directory = 'C:/Users/nfdlam/OneDrive - The Hong Kong Polytechnic University/images/CXR-GAN/DRR'

DSC_bone_list = []
Jaccard_bone_list = []
DSC_lung_list = []
Jaccard_lung_list = []

for patient_code in ['0005','0404','0612']:
    print(patient_code)
    # Information for each patient
    if patient_code == '0005':
        axial_slice = 115
        coronal_slice = 257
        sagittal_slice = 329

        origin = [-178.34, -189.083, -942.0] # R, A, I
        VoxelSize = [0.74, 0.74, 1.0]  # LR, AP, IS
        
        validation_bone_file = '0005-bone.seg.nrrd'
        validation_lung_file = '0005-lung.seg.nrrd'
        auto_bone_file = '0005_bone_autosegmentation.npy'
        auto_lung_file = '0005_lung_autosegmentation.npy'
        
    elif patient_code =='0404':
        axial_slice=24
        coronal_slice=256
        sagittal_slice=272

        origin = [-213.436, -220.272, -352.0] # R, A, I
        VoxelSize = [0.862, 0.862, 5.0]  # LR, AP, IS

        validation_bone_file = '0404-bone.seg.nrrd'
        auto_bone_file = '0404_bone_autosegmentation.npy'
        validation_lung_file = '0404-lung.seg.nrrd'
        auto_lung_file = '0404_lung_autosegmentation.npy'
        
    elif patient_code=='0612':
        axial_slice=31
        coronal_slice=239
        sagittal_slice=203

        origin = [-177.4, -180.0, -306.75] # R, A, I
        VoxelSize = [0.703125, 0.703125, 5.0]  # LR, AP, IS

        validation_bone_file = '0612-bone.seg.nrrd'
        auto_bone_file = '0612_bone_autosegmentation.npy'
        validation_lung_file = '0612-lung.seg.nrrd'
        auto_lung_file = '0612_lung_autosegmentation.npy'

    tissue_range = ["bone","lung"]
    # VALIDATION FILE PATH
    directoryPath_validation = pathlib.Path("D:/data/CT-Covid-19-August2020/validation_segmentations/")
    #print(directoryPath_validation)
    directoryPath_auto = pathlib.Path("D:/data/CT-Covid-19-August2020/auto_segmentation/")
    #print(directoryPath_auto)

    for tissue in tissue_range:
        print(tissue)
        if tissue =="bone":
            validation_file = validation_bone_file
            auto_file = auto_bone_file
        if tissue =="lung":
            validation_file = validation_lung_file
            auto_file = auto_lung_file

        # LOAD VALIDATION FILE
        validation_file_path = os.path.join(directoryPath_validation, validation_file)

        # Load image
        reader = sitk.ImageFileReader()
        reader.SetFileName(validation_file_path)
        reader.LoadPrivateTagsOn()
        reader.ReadImageInformation()
        # Read Metadata
        for k in reader.GetMetaDataKeys():
            v = reader.GetMetaData(k)
            #print(f"({k}) = = \"{v}\"")
        image = reader.Execute();
        validation_array = sitk.GetArrayFromImage(image)

        axial_validation = validation_array[axial_slice,:,:]
        coronal_validation = validation_array[:,coronal_slice,:]
        sagittal_validation = validation_array[:,:,sagittal_slice]

        #plt.imshow(axial_validation)
        #plt.plot

        # LOAD AUTO FILE
        auto_array = np.load(os.path.join(directoryPath_auto, auto_file))
        axial_auto = auto_array[axial_slice,:,:]
        coronal_auto = auto_array[:,coronal_slice,:]
        sagittal_auto = auto_array[:,:,sagittal_slice]
        
        # CALCULATE METRICS
        DSC_axial = Metrics.DiceSimilarityCoefficient(axial_auto, axial_validation)
        DSC_coronal = Metrics.DiceSimilarityCoefficient(coronal_auto, coronal_validation)
        DSC_sagittal = Metrics.DiceSimilarityCoefficient(sagittal_auto, sagittal_validation)
        Jaccard_axial = Metrics.JaccardIndex(axial_auto, axial_validation)
        Jaccard_coronal = Metrics.JaccardIndex(coronal_auto, coronal_validation)
        Jaccard_sagittal = Metrics.JaccardIndex(sagittal_auto, sagittal_validation)
        print("DSC for "+tissue+": "+str([DSC_axial, DSC_coronal, DSC_sagittal]))
        print("Jaccard for "+tissue+": "+str([Jaccard_axial, Jaccard_coronal, Jaccard_sagittal]))
        if tissue == "lung":
            DSC_lung_list.append(DSC_axial)
            DSC_lung_list.append(DSC_coronal)
            DSC_lung_list.append(DSC_sagittal)
            Jaccard_lung_list.append(Jaccard_axial)
            Jaccard_lung_list.append(Jaccard_coronal)
            Jaccard_lung_list.append(Jaccard_sagittal)
        elif tissue == "bone":
            DSC_bone_list.append(DSC_axial)
            DSC_bone_list.append(DSC_coronal)
            DSC_bone_list.append(DSC_sagittal)
            Jaccard_bone_list.append(Jaccard_axial)
            Jaccard_bone_list.append(Jaccard_coronal)
            Jaccard_bone_list.append(Jaccard_sagittal)
            
        extents =[origin[0]-0.5*VoxelSize[0], origin[0]-0.5*VoxelSize[0]+VoxelSize[0]*(auto_array.shape[1]),
                  origin[1]-0.5*VoxelSize[0], origin[1]-0.5*VoxelSize[0]+VoxelSize[1]*(auto_array.shape[2]),
                  origin[2]-0.5*VoxelSize[0], origin[2]-0.5*VoxelSize[0]+VoxelSize[2]*(auto_array.shape[0])]
        #print(extents)
        extents_coronal = [[extents[4], extents[5]], [extents[0], extents[1]]]
        extents_axial = [[extents[0], extents[1]], [extents[2], extents[3]]]
        #print(extents_axial)
        #print(Metrics.MCCD(axial_auto, axial_validation, extents_axial))
        
        fig, (ax1, ax2) = plt.subplots(1, 2)
        fig.suptitle('Left: auto, Right: validation')
        ax1.imshow(axial_auto)
        ax2.imshow(axial_validation)
        fig.savefig(os.path.join(savefig_directory,patient_code+"_"+tissue+'_autoVSvalidation.png'), dpi=150)

# Total Output
meanDSC_bone = np.mean(DSC_bone_list)
meanJaccard_bone = np.mean(Jaccard_bone_list)
print("BONE:Mean DSC: " + str(meanDSC_bone) + ", Mean Jaccard: " + str(meanJaccard_bone))
meanDSC_lung = np.mean(DSC_lung_list)
meanJaccard_lung = np.mean(Jaccard_lung_list)
print("LUNG:Mean DSC: " + str(meanDSC_lung) + ", Mean Jaccard: " + str(meanJaccard_lung))
# Out:
# 0005
# bone
# DSC for bone: [0.9049041333461798, 0.9515235457063712, 0.9597197898423818]
# Jaccard for bone: [0.8263241245820869, 0.9075297225891678, 0.9225589225589226]
# lung
# DSC for lung: [0.9920727089118909, 0.9826573469925453, 0.9896433660123769]
# Jaccard for lung: [0.9842701132151087, 0.9659059748331861, 0.9794990528309829]
# 0404
# bone
# DSC for bone: [0.8413793103448276, 0.809499747347145, 0.8101535187718498]
# Jaccard for bone: [0.7261904761904762, 0.6799660441426146, 0.6808891159938681]
# lung
# DSC for lung: [0.9944997270856951, 0.9960790720470512, 0.96]
# Jaccard for lung: [0.9890596291965926, 0.9921887713588283, 0.9230769230769231]
# 0612
# bone
# DSC for bone: [0.8976736619489182, 0.6723910171730515, 0.8807947019867549]
# Jaccard for bone: [0.814344746162928, 0.5064676616915423, 0.7869822485207101]
# lung
# DSC for lung: [0.9940898650218082, 0.9949303538908303, 0.9788243668070467]
# Jaccard for lung: [0.9882491789819376, 0.9899118511263467, 0.9585269516728625]
# ...

# %%
print(validation_array.shape)
auto_points = ImageProcessing.mask2points(axial_auto)
val_points = ImageProcessing.mask2points(axial_validation)
# Out:
# (67, 512, 512)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-6e44094e5ba6> in <module>()
#       1 print(validation_array.shape)
# ----> 2 auto_points = ImageProcessing.mask2points(axial_auto)
#       3 val_points = ImageProcessing.mask2points(axial_validation)
#
# TypeError: mask2points() missing 1 required positional argument: 'extents'
